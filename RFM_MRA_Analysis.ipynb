# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_excel('C:/Users/hp/Desktop/KNIME/Sales_Data.xlsx',parse_dates=['ORDERDATE'])

# %%
df.head(40)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 0         10107               30      95.70                2   2871.00
# 1         10121               34      81.35                5   2765.90
# 2         10134               41      94.74                2   3884.34
# 3         10145               45      83.26                6   3746.70
# 4         10168               36      96.66                1   3479.76
# 5         10180               29      86.13                9   2497.77
# 6         10188               48     114.84                1   5512.32
# 7         10211               41     114.84               14   4708.44
# 8         10223               37     107.18                1   3965.66
# 9         10237               23     101.44                7   2333.12
# 10        10251               28     113.88                2   3188.64
# 11        10263               34     108.14                2   3676.76
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.tail().T
# Out:
#                                        2742                     2743  \
# ORDERNUMBER                           10350                    10373
# QUANTITYORDERED                          20                       29
# PRICEEACH                            112.22                   137.19
# ORDERLINENUMBER                          15                        1
# SALES                                2244.4                  3978.51
# ORDERDATE                             43801                    43861
# DAYS_SINCE_LASTORDER                   2924                     2865
# STATUS                              Shipped                  Shipped
# PRODUCTLINE                           Ships                    Ships
# MSRP                                     54                       54
# PRODUCTCODE                        S72_3212                 S72_3212
# CUSTOMERNAME          Euro Shopping Channel  Oulu Toy Supplies, Inc.
# PHONE                        (91) 555 94 44               981-443655
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
df.describe().T
# Out:
#                        count          mean          std       min        25%  \
# ORDERNUMBER           2747.0  10259.761558    91.877521  10100.00  10181.000
# QUANTITYORDERED       2747.0     35.103021     9.762135      6.00     27.000
# PRICEEACH             2747.0    101.098951    42.042548     26.88     68.745
# ORDERLINENUMBER       2747.0      6.491081     4.230544      1.00      3.000
# SALES                 2747.0   3553.047583  1838.953901    482.13   2204.350
# DAYS_SINCE_LASTORDER  2747.0   1757.085912   819.280576     42.00   1077.000
# MSRP                  2747.0    100.691664    40.114802     33.00     68.000
#
#                            50%        75%       max
# ORDERNUMBER           10264.00  10334.500  10425.00
# QUANTITYORDERED          35.00     43.000     97.00
# PRICEEACH                95.55    127.100    252.87
# ORDERLINENUMBER           6.00      9.000     18.00
# SALES                  3184.80   4503.095  14082.80
# ...

# %%
df.describe(include=['O']).T
# Out:
#                  count unique                    top  freq
# STATUS            2747      6                Shipped  2541
# PRODUCTLINE       2747      7           Classic Cars   949
# PRODUCTCODE       2747    109               S18_3232    51
# CUSTOMERNAME      2747     89  Euro Shopping Channel   259
# PHONE             2747     88         (91) 555 94 44   259
# ADDRESSLINE1      2747     89     C/ Moralzarzal, 86   259
# CITY              2747     71                 Madrid   304
# POSTALCODE        2747     73                  28034   259
# COUNTRY           2747     19                    USA   928
# CONTACTLASTNAME   2747     76                 Freyre   259
# CONTACTFIRSTNAME  2747     72                  Diego   259
# DEALSIZE          2747      3                 Medium  1349

# %%
df.ORDERNUMBER.nunique()
# Out:
# 298

# %%
df.CUSTOMERNAME.unique()
# Out:
# array(['Land of Toys Inc.', 'Reims Collectables', 'Lyon Souveniers',
#        'Toys4GrownUps.com', 'Technics Stores Inc.',
#        'Daedalus Designs Imports', 'Herkku Gifts', 'Auto Canal Petit',
#        'Australian Collectors, Co.', 'Vitachrome Inc.',
#        'Tekni Collectables Inc.', 'Gift Depot Inc.', 'La Rochelle Gifts',
#        "Marta's Replicas Co.", 'Toys of Finland, Co.',
#        'Baane Mini Imports', 'Diecast Classics Inc.',
#        'Salzburg Collectables', 'Souveniers And Things Co.',
#        'FunGiftIdeas.com', 'UK Collectables, Ltd.',
#        'Euro Shopping Channel', 'Volvo Model Replicas, Co',
#        'Corrida Auto Replicas, Ltd', 'Dragon Souveniers, Ltd.',
#        'Classic Legends Inc.', 'Australian Gift Network, Co',
#        'Classic Gift Ideas, Inc', 'Saveley & Henriot, Co.',
#        'Canadian Gift Exchange Network', 'West Coast Collectables Co.',
#        'Cambridge Collectables Co.', 'Super Scale Inc.',
# ...

# %%
df[df.PHONE=='6175558555']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 13          10285               36     113.88                6  4099.68
# 46          10369               41     110.12                2  4514.92
# 63          10285               47     137.97                9  6484.59
# 87          10285               27     201.41                8  5438.07
# 140         10305               38     175.81               13  6680.78
# 153         10147               48     192.62                7  9245.76
# 239         10285               49     140.08                5  6863.92
# 278         10147               31     112.74                5  3494.94
# 328         10147               21      63.84                8  1340.64
# 366         10305               38     125.61                5  4773.18
# 379         10147               33      97.89                4  3230.37
# 474         10369               44     210.01                8  9240.44
# ...

# %%
num_col=df.select_dtypes(['int64','float64'])

# %%
plt.figure(figsize=(10,7))
for i in range(len(num_col.columns)):
    plt.subplot(3,2,i+1)
    sns.boxplot(data=num_col,x=num_col.columns[i])
    plt.tight_layout()
plt.savefig('num_col.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 3
#       1 plt.figure(figsize=(10,7))
#       2 for i in range(len(num_col.columns)):
# ----> 3     plt.subplot(3,2,i+1)
#       4     sns.boxplot(data=num_col,x=num_col.columns[i])
#       5     plt.tight_layout()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1296, in subplot(*args, **kwargs)
#    1293 fig = gcf()
#    1295 # First, search for an existing subplot with a matching spec.
# -> 1296 key = SubplotSpec._from_subplot_args(fig, args)
#    1298 for ax in fig.axes:
#    1299     # if we found an Axes at the position sort out if we can re-use it
#    1300     if ax.get_subplotspec() == key:
#    1301         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:594, in SubplotSpec._from_subplot_args(figure, args)
#     592 else:
# ...

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df,x='QUANTITYORDERED',kde=True)
plt.title('QUANTITYORDERED DISTRIBUTION');

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df,x='PRICEEACH',kde=True)
plt.title('PRICEEACH DISTRIBUTION');

# %%
mba=pd.read_csv('C:/Users/hp/Desktop/KNIME/dataset_group.csv',parse_dates=['Date'])

# %%
mba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  datetime64[ns]
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 483.9+ KB

# %%
mba.head()
# Out:
#         Date  Order_id        Product
# 0 2018-01-01         1         yogurt
# 1 2018-01-01         1           pork
# 2 2018-01-01         1  sandwich bags
# 3 2018-01-01         1     lunch meat
# 4 2018-01-01         1   all- purpose

# %%
mba.tail()
# Out:
#             Date  Order_id            Product
# 20636 2020-02-25      1138               soda
# 20637 2020-02-25      1138       paper towels
# 20638 2020-02-26      1139               soda
# 20639 2020-02-26      1139  laundry detergent
# 20640 2020-02-26      1139            shampoo

# %%
mba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  datetime64[ns]
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 483.9+ KB

# %%
mba.describe().T
# Out:
#             count        mean         std  min    25%    50%    75%     max
# Order_id  20641.0  575.986289  328.557078  1.0  292.0  581.0  862.0  1139.0

# %%
mba.describe(include='object').T
# Out:
#          count unique      top freq
# Product  20641     37  poultry  640

# %%
mba.Product.nunique()
# Out:
# 37

# %%
mba.Product.value_counts()
# Out:
# Index(['poultry', 'soda', 'cereals', 'ice cream', 'cheeses', 'waffles', 'soap',
#        'bagels', 'lunch meat', 'juice', 'eggs', 'toilet paper', 'dinner rolls',
#        'aluminum foil', 'coffee/tea', 'shampoo', 'beef', 'paper towels',
#        'flour', 'butter', 'milk', 'mixes', 'dishwashing liquid/detergent',
#        'all- purpose', 'ketchup', 'yogurt', 'individual meals', 'tortillas',
#        'pasta', 'laundry detergent', 'spaghetti sauce', 'sandwich bags',
#        'sugar', 'pork', 'fruits', 'sandwich loaves', 'hand soap'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=mba,y='Product',order=mba.Product.value_counts().keys(),)
plt.savefig('grocery_s.png');

# %%
mba.Product.value_counts().tail()
# Out:
# sugar              533
# pork               531
# fruits             529
# sandwich loaves    523
# hand soap          502
# Name: Product, dtype: int64

# %%
mba.Order_id.nunique()
# Out:
# 1139

# %%
mba
# Out:
#             Order_id            Product
# Date
# 2018-01-01         1             yogurt
# 2018-01-01         1               pork
# 2018-01-01         1      sandwich bags
# 2018-01-01         1         lunch meat
# 2018-01-01         1       all- purpose
# ...              ...                ...
# 2020-02-25      1138               soda
# 2020-02-25      1138       paper towels
# 2020-02-26      1139               soda
# 2020-02-26      1139  laundry detergent
# 2020-02-26      1139            shampoo
#
# [20641 rows x 2 columns]

# %%
mba.groupby('Order_id').count()['Product']
# Out:
# Order_id
# 1       19
# 2       20
# 3       27
# 4        6
# 5       20
#         ..
# 1135    30
# 1136    20
# 1137    23
# 1138    19
# 1139     3
# Name: Product, Length: 1139, dtype: int64

# %%
mba.groupby('Date').count()['Product']sum
# Out:
#             Product
# Date
# 2018-01-01       39
# 2018-01-02       15
# 2018-01-03      127
# 2018-01-04       28
# 2018-01-05       37
# ...             ...
# 2020-10-02       22
# 2020-11-01       87
# 2020-11-02       19
# 2020-12-01       27
# 2020-12-02       33
#
# [603 rows x 1 columns]
